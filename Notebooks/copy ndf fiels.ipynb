# %%
import os, shutil
import pandas as pd
from datetime import datetime
import glob

# %%
csv_files = pd.read_csv('/media/mfpleite/LaCie_1/ML_pyecog_2/data_from_Mikail/all_files_paths.csv')#
base_RDSS_path = '/home/mfpleite/Documents/RDSS/'
base_destination_folder = '/media/mfpleite/LaCie_1/ML_pyecog_2/data_from_Mikail/ndf'

# %%
csv_files.sort()
csv_files_list = csv_files.values.tolist()
csv_files_list.sort()
origin_files_list = [base_RDSS_path + '/'.join(f[0].split('/')[-5:]) for f in csv_files_list]
destination_file_list = [base_destination_folder + '/'.join(f[0].split('/')[-1:]) for f in csv_files_list]
# Out:
# /home/mfpleite/anaconda3/envs/pyecog2_env/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: sort(....) is deprecated, use sort_index(.....)
#   """Entry point for launching an IPython kernel.

# %%
csv_files_list
# Out:
# [['/mnt/gpfs/live/ritd-ag-project-rd003y-dmkul63/rat_telemetry/Rig2/2018/ndf/M1532940956.ndf'],
#  ['/mnt/gpfs/live/ritd-ag-project-rd003y-dmkul63/rat_telemetry/Rig2/2018/ndf/M1532944556.ndf'],
#  ['/mnt/gpfs/live/ritd-ag-project-rd003y-dmkul63/rat_telemetry/Rig2/2018/ndf/M1532948156.ndf'],
#  ['/mnt/gpfs/live/ritd-ag-project-rd003y-dmkul63/rat_telemetry/Rig2/2018/ndf/M1532951756.ndf'],
#  ['/mnt/gpfs/live/ritd-ag-project-rd003y-dmkul63/rat_telemetry/Rig2/2018/ndf/M1532955356.ndf'],
#  ['/mnt/gpfs/live/ritd-ag-project-rd003y-dmkul63/rat_telemetry/Rig2/2018/ndf/M1532958956.ndf'],
#  ['/mnt/gpfs/live/ritd-ag-project-rd003y-dmkul63/rat_telemetry/Rig2/2018/ndf/M1532962556.ndf'],
#  ['/mnt/gpfs/live/ritd-ag-project-rd003y-dmkul63/rat_telemetry/Rig2/2018/ndf/M1532966156.ndf'],
#  ['/mnt/gpfs/live/ritd-ag-project-rd003y-dmkul63/rat_telemetry/Rig2/2018/ndf/M1532969756.ndf'],
#  ['/mnt/gpfs/live/ritd-ag-project-rd003y-dmkul63/rat_telemetry/Rig2/2018/ndf/M1532973356.ndf'],
# ...

# %%
for file in csv_files_list:
    print(file)
# Out:
# ['/mnt/gpfs/live/ritd-ag-project-rd003y-dmkul63/rat_telemetry/Rig2/2018/ndf/M1532940956.ndf']
# ['/mnt/gpfs/live/ritd-ag-project-rd003y-dmkul63/rat_telemetry/Rig2/2018/ndf/M1532944556.ndf']
# ['/mnt/gpfs/live/ritd-ag-project-rd003y-dmkul63/rat_telemetry/Rig2/2018/ndf/M1532948156.ndf']
# ['/mnt/gpfs/live/ritd-ag-project-rd003y-dmkul63/rat_telemetry/Rig2/2018/ndf/M1532951756.ndf']
# ['/mnt/gpfs/live/ritd-ag-project-rd003y-dmkul63/rat_telemetry/Rig2/2018/ndf/M1532955356.ndf']
# ['/mnt/gpfs/live/ritd-ag-project-rd003y-dmkul63/rat_telemetry/Rig2/2018/ndf/M1532958956.ndf']
# ['/mnt/gpfs/live/ritd-ag-project-rd003y-dmkul63/rat_telemetry/Rig2/2018/ndf/M1532962556.ndf']
# ['/mnt/gpfs/live/ritd-ag-project-rd003y-dmkul63/rat_telemetry/Rig2/2018/ndf/M1532966156.ndf']
# ['/mnt/gpfs/live/ritd-ag-project-rd003y-dmkul63/rat_telemetry/Rig2/2018/ndf/M1532969756.ndf']
# ['/mnt/gpfs/live/ritd-ag-project-rd003y-dmkul63/rat_telemetry/Rig2/2018/ndf/M1532973356.ndf']
# ...

# %%
datetime.fromtimestamp(1532940229).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2018-07-30 10:43:49'

# %%
len(csv_file_list)
# Out:
# 2872

# %%
destination_file_list[2]
# Out:
# '/media/mfpleite/LaCie_1/ML_pyecog_2/data_from_Mikail/ndf/'

# %%
shutil.copyfile(origin_files_list[0],destination_file_list[0])
# Out:
# '/media/mfpleite/LaCie_1/ML_pyecog_2/data_from_Mikail/ndfM1532940956.ndf'

# %%
for i in range(len(origin_files_list)):
    shutil.copyfile(origin_files_list[i],destination_file_list[i])
    print('copied',i,'of',len(origin_files_list),'(',origin_files_list[i],'to',destination_file_list[i],')')
# Out:
# copied 0 of 2872 ( /home/mfpleite/Documents/RDSS/rat_telemetry/Rig2/2018/ndf/M1532940956.ndf to /media/mfpleite/LaCie_1/ML_pyecog_2/data_from_Mikail/ndfM1532940956.ndf )
# copied 1 of 2872 ( /home/mfpleite/Documents/RDSS/rat_telemetry/Rig2/2018/ndf/M1532944556.ndf to /media/mfpleite/LaCie_1/ML_pyecog_2/data_from_Mikail/ndfM1532944556.ndf )
# copied 2 of 2872 ( /home/mfpleite/Documents/RDSS/rat_telemetry/Rig2/2018/ndf/M1532948156.ndf to /media/mfpleite/LaCie_1/ML_pyecog_2/data_from_Mikail/ndfM1532948156.ndf )
# copied 3 of 2872 ( /home/mfpleite/Documents/RDSS/rat_telemetry/Rig2/2018/ndf/M1532951756.ndf to /media/mfpleite/LaCie_1/ML_pyecog_2/data_from_Mikail/ndfM1532951756.ndf )
# copied 4 of 2872 ( /home/mfpleite/Documents/RDSS/rat_telemetry/Rig2/2018/ndf/M1532955356.ndf to /media/mfpleite/LaCie_1/ML_pyecog_2/data_from_Mikail/ndfM1532955356.ndf )
# ...

# %%
a = glob.glob('/media/mfpleite/LaCie_1/ML_pyecog_2/data_from_ele//*/')

# %%
os.listdir('/media/mfpleite/LaCie_1/ML_pyecog_2/data_from_ele')
# Out:
# ['h5_2', 'h5_8', 'h5_129', 'h5_211']

# %%
a[1] in a
# Out:
# True
